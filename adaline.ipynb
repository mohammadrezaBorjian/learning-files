# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])

y = np.array([-1, 1, 1, 1])
input_sample_count=y.size


np.random.seed(1)
eta = 0.01   
epochs = 900 
w = np.random.randn(2) 
b = np.random.randn()  

def predict(x):
    return np.sum((x * w)) + b 


errors = []

for epoch_number in range(epochs):
    sum_error=0
    for i in range(input_sample_count):
        p2=input[i].transpose()
        a=np.matmul(w,p2)
        a=a+bias
        w=w+eta*(y[i]-a)*input[i]
        change_weight=max(eta*(y[i]-a)*input[i])
        bias=bias+eta*(y[i]-a)
        sum_error+=(y[i]-a)**2
    print('epoch:',epoch_number,'weight:',w,'bias:',bias,'error:',(y[i]-a)**2)
    errors.append(sum_error)
    
plt.plot(errors)
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.title('Training Error of Adaline')
plt.show()

plt.figure()
for xi, target in zip(X, y):
    output = predict(xi)
    print(output)
    color = 'blue' if output >= 0 else 'red'
    plt.scatter(xi[0], xi[1], c=color, s=100)

x_vals = np.linspace(-0.5, 1.5, 100)  
y_vals = -(w[0] * x_vals + b) / w[1]  
plt.plot(x_vals, y_vals, 'k--',color = 'green', label='Decision Boundary')

plt.xlabel('Input 1')
plt.ylabel('Input 2')
plt.title('Adaline Predictions for OR with Decision Boundary')
plt.legend(['Red = 1', 'Blue = 0'])
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)
plt.grid()
plt.show()
# Out:
# epoch: 0 weight: [ 1.62178559 -0.59177263] bias: [-0.19787471] error: [0.02994746]
# epoch: 1 weight: [ 1.618933   -0.57230988] bias: [-0.19077187] error: [0.02208403]
# epoch: 2 weight: [ 1.61581093 -0.55334241] bias: [-0.18427449] error: [0.01576862]
# epoch: 3 weight: [ 1.6124412  -0.53484602] bias: [-0.17834372] error: [0.01078783]
# epoch: 4 weight: [ 1.60884424 -0.51679797] bias: [-0.17294318] error: [0.00695537]
# epoch: 5 weight: [ 1.60503913 -0.49917686] bias: [-0.16803875] error: [0.00410874]
# epoch: 6 weight: [ 1.60104371 -0.48196256] bias: [-0.16359843] error: [0.00210627]
# epoch: 7 weight: [ 1.59687465 -0.46513616] bias: [-0.15959225] error: [0.00082456]
# epoch: 8 weight: [ 1.59254755 -0.44867984] bias: [-0.1559921] error: [0.00015623]
# epoch: 9 weight: [ 1.58807696 -0.43257685] bias: [-0.15277165] error: [7.91206598e-06]
# epoch: 10 weight: [ 1.58347647 -0.41681141] bias: [-0.14990621] error: [0.0002985]
# ...
